# %%
from bs4 import BeautifulSoup
import requests
import time
from urllib.request import urlopen
import ssl
import re
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
from os.path import splitext, basename

# %%
url='https://www.espncricinfo.com/records/tournament/averages-batting/icc-cricket-world-cup-2023-24-15338'

r= requests.get(url)

# %%
r='<div jsname="LS81yb" class="sWfpOe" data-index="0"><div aria-label="Standings section"><div></div><div class="jXpA9e Ui5IUc" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQuEt6BAgBECU"><div><table class="Jzru1c"><tbody><tr><th class="tuzU3e w2Mymf Lcskac" aria-hidden="true"></th><th class="fbf28d wxNiFd tuzU3e ey2qkf" role="columnheader" scope="col"><div class="YCyuEf">Rank</div></th><th class="ey2qkf tuzU3e QI3dEzyb K2ENGc wxNiFd Pvbt4c jooWBf eIMmHd lq7Dvb" role="columnheader" scope="col"><div class="d8zVje">Team</div></th><th class="tuzU3e xkW0Cc eIMmHd vZXnld" style="width:25px;min-width:25px" role="columnheader" scope="col"><div><span aria-hidden="true">M</span><span class="YCyuEf">Matches</span></div></th><th class="tuzU3e xkW0Cc eIMmHd vZXnld" style="width:25px;min-width:25px" role="columnheader" scope="col"><div><span aria-hidden="true">W</span><span class="YCyuEf">Won</span></div></th><th class="tuzU3e xkW0Cc eIMmHd vZXnld" style="width:25px;min-width:25px" role="columnheader" scope="col"><div><span aria-hidden="true">L</span><span class="YCyuEf">Lost</span></div></th><th class="tuzU3e xkW0Cc eIMmHd vZXnld" style="width:50px;min-width:50px" role="columnheader" scope="col"><div><span aria-hidden="true">NRR</span><span class="YCyuEf">Net run rate</span></div></th><th class="tuzU3e xkW0Cc eIMmHd vZXnld" style="width:25px;min-width:25px" role="columnheader" scope="col"><div><span aria-hidden="true">Pts</span><span class="YCyuEf">Points</span></div></th><th class="tuzU3e xkW0Cc eIMmHd vZXnld kRLtzc" style="width:100px;min-width:100px" role="columnheader" scope="col"><div><span aria-hidden="true">Last 5</span><span class="YCyuEf">Last 5 matches</span></div></th></tr><tr jscontroller="cvgK0e" aria-label="IND" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#2255a4" data-team-fullpage-title-for-transition="" data-team-mid="/m/024nj1" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARAm"><td class="snctkc Lcskac e9fBA jooWBf xL0E7c" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff;border-top-width:1px;border-top-style:solid"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">1</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/mlXOOB9HXxLpoeS2dHSgGA_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG xL0E7c"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">IND</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA xL0E7c"><div>9</div></td><td class="xkW0Cc snctkc e9fBA xL0E7c"><div>9</div></td><td class="xkW0Cc snctkc e9fBA xL0E7c"><div>0</div></td><td class="xkW0Cc snctkc e9fBA xL0E7c"><div>+2.570</div></td><td class="xkW0Cc snctkc e9fBA xL0E7c"><div>18</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc xL0E7c" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:31px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;top:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-bottom-color:#4285f4;bottom:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="SA" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#0E793B" data-team-fullpage-title-for-transition="" data-team-mid="/m/038zy5" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARAu"><td class="snctkc Lcskac e9fBA jooWBf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">2</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/EGwD4_SUlmwZWbnHhcmTPA_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">SA</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA"><div>9</div></td><td class="xkW0Cc snctkc e9fBA"><div>7</div></td><td class="xkW0Cc snctkc e9fBA"><div>2</div></td><td class="xkW0Cc snctkc e9fBA"><div>+1.261</div></td><td class="xkW0Cc snctkc e9fBA"><div>14</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Win</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="AUS" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#03672e" data-team-fullpage-title-for-transition="" data-team-mid="/m/020wyp" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARA2"><td class="snctkc Lcskac e9fBA jooWBf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">3</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/jSgw5z0EPOLzdUi-Aomq7Q_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">AUS</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA"><div>9</div></td><td class="xkW0Cc snctkc e9fBA"><div>7</div></td><td class="xkW0Cc snctkc e9fBA"><div>2</div></td><td class="xkW0Cc snctkc e9fBA"><div>+0.841</div></td><td class="xkW0Cc snctkc e9fBA"><div>14</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="NZ" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#000000" data-team-fullpage-title-for-transition="" data-team-mid="/m/02fbb5" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARA-"><td class="snctkc Lcskac e9fBA jooWBf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">4</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/vLzv_L6wZJ4ygGlIJLUc1A_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">NZ</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA"><div>9</div></td><td class="xkW0Cc snctkc e9fBA"><div>5</div></td><td class="xkW0Cc snctkc e9fBA"><div>4</div></td><td class="xkW0Cc snctkc e9fBA"><div>+0.743</div></td><td class="xkW0Cc snctkc e9fBA"><div>10</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Win</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="PAK" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#12453C" data-team-fullpage-title-for-transition="" data-team-mid="/m/038_0z" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARBG"><td class="snctkc Lcskac e9fBA jooWBf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">5</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/-I9tpg9uetJjQNCh15jmKw_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">PAK</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA"><div>9</div></td><td class="xkW0Cc snctkc e9fBA"><div>4</div></td><td class="xkW0Cc snctkc e9fBA"><div>5</div></td><td class="xkW0Cc snctkc e9fBA"><div>-0.199</div></td><td class="xkW0Cc snctkc e9fBA"><div>8</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Loss</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="AFG" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#8b7031" data-team-fullpage-title-for-transition="" data-team-mid="/m/076tnc" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARBO"><td class="snctkc Lcskac e9fBA jooWBf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">6</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/8rwaXVaUKfdJq31QgGtQrw_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">AFG</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA"><div>9</div></td><td class="xkW0Cc snctkc e9fBA"><div>4</div></td><td class="xkW0Cc snctkc e9fBA"><div>5</div></td><td class="xkW0Cc snctkc e9fBA"><div>-0.336</div></td><td class="xkW0Cc snctkc e9fBA"><div>8</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="ENG" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#152a5e" data-team-fullpage-title-for-transition="" data-team-mid="/m/038zh6" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARBW"><td class="snctkc Lcskac e9fBA jooWBf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">7</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/DTqIL8Ba3KIuxGkpXw5ayA_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">ENG</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA"><div>9</div></td><td class="xkW0Cc snctkc e9fBA"><div>3</div></td><td class="xkW0Cc snctkc e9fBA"><div>6</div></td><td class="xkW0Cc snctkc e9fBA"><div>-0.572</div></td><td class="xkW0Cc snctkc e9fBA"><div>6</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Win</div><div class="YCyuEf">Win</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="BAN" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#17481e" data-team-fullpage-title-for-transition="" data-team-mid="/m/038_6w" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARBe"><td class="snctkc Lcskac e9fBA jooWBf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">8</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/uTQstsRqQKZC-VUZWaNi0w_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">BAN</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA"><div>9</div></td><td class="xkW0Cc snctkc e9fBA"><div>2</div></td><td class="xkW0Cc snctkc e9fBA"><div>7</div></td><td class="xkW0Cc snctkc e9fBA"><div>-1.087</div></td><td class="xkW0Cc snctkc e9fBA"><div>4</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Loss</div><div class="YCyuEf">Win</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="SL" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#152a5e" data-team-fullpage-title-for-transition="" data-team-mid="/m/023fxp" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARBm"><td class="snctkc Lcskac e9fBA jooWBf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">9</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/-6moqr0dxYpIhERhbiVLSA_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">SL</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA"><div>9</div></td><td class="xkW0Cc snctkc e9fBA"><div>2</div></td><td class="xkW0Cc snctkc e9fBA"><div>7</div></td><td class="xkW0Cc snctkc e9fBA"><div>-1.419</div></td><td class="xkW0Cc snctkc e9fBA"><div>4</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Win</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr><tr jscontroller="cvgK0e" aria-label="NED" class="imso-loa imso-hov" data-league-mid="" data-should-expand-to-team-fullpage="true" data-sport="5" data-team-fullpage-color-for-transition="#ef6c00" data-team-fullpage-title-for-transition="" data-team-mid="/m/06rmgh" role="link" tabindex="0" jsaction="rcuQ6b:npT2md;hOPlV" data-ved="2ahUKEwjRo8fnof2DAxV1lK8BHcOODrsQ_NIKegQIARBu"><td class="snctkc Lcskac e9fBA jooWBf bWoKCf" aria-hidden="true"></td><td class="fbf28d wxNiFd B1pJhb e9fBA AXYSPc"><div class="Rqwdve RQCbNe" style="border-color:#fff"><div class="Xne9qe"><span class="YCyuEf"></span></div></div><div class="gDo0uc tgaaSb"><div class="iU5t0d">10</div></div><div class="tgaaSb" aria-hidden="true"><span class="iU5t0d b8Oacc fz3Rib"><img class="imso_btl__mh-logo" alt="" src="//ssl.gstatic.com/onebox/media/sports/logos/8GEqzfLegwFFpe6X2BODTg_48x48.png" style="width:24px;height:24px"></span></div><div class="tgaaSb" style="width:12px"></div></td><td class="fbf28d B1pJhb e9fBA fI7lFd GAb8Mc FnBtG bWoKCf"><div class="e6E1Yd"><div class="imso-hide-overflow C1gYkd" role="link"><span class="ellipsisize hsKSJe">NED</span><br></div></div></td><td class="xkW0Cc snctkc e9fBA bWoKCf"><div>9</div></td><td class="xkW0Cc snctkc e9fBA bWoKCf"><div>2</div></td><td class="xkW0Cc snctkc e9fBA bWoKCf"><div>7</div></td><td class="xkW0Cc snctkc e9fBA bWoKCf"><div>-1.825</div></td><td class="xkW0Cc snctkc e9fBA bWoKCf"><div>4</div></td><td class="gwqH4e xkW0Cc snctkc e9fBA kRLtzc bWoKCf" role="cell" tabindex="0" jsaction="ipUFbd"><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Loss</div><div class="YCyuEf">Win</div><div class="YCyuEf">Loss</div><div jsname="U4QKYc" class="t0t45c II8W2d" jscontroller="imurKb" data-as="5" data-ca="" data-dir="ltr" data-position-left="6" data-tooltip-width="90" jsaction="kHBd4e:ZYIfFd"><div jsname="haAclf" class="qRlaod" style="top:9px;left:-49px"><span jsname="fmcmS" class="Y86vEf zHcLxe" style="background-color:#4285f4;bottom:0;width:90px" aria-hidden="true">Most recent match</span><div jsname="hFsbo" class="npJGSb" style="border-top-color:#4285f4;top:0;left:50px"></div></div>  <div class="mzZLbb" aria-hidden="true"> <div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-w">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div><div class="XqaACe BPu3kf" aria-labelledby="l5l-l">  <img src="data:image/svg+xml;base64,..." class="nB9CIe" alt="">  </div> </div> </div></td><td class="w2Mymf e9fBA" aria-hidden="true"></td></tr></tbody></table></div></div></div></div>'

# %%
r
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(r.text,"html.parser")

table = soup.find("table", class_=lambda x: x and "ds-table" in x)

# %%
print(table)
# Out:
# <table class="ds-w-full ds-table ds-table-xs ds-table-auto ds-w-full ds-overflow-scroll ds-scrollbar-hide"><thead class="ds-bg-fill-content-alternate ds-text-left"><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Player</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Span</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Mat</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Inns</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">NO</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Runs</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor
# ...

# %%
header = table.find("thead")

# %%
header.text
# Out:
# 'PlayerSpanMatInnsNORunsHSAveSR100500'

# %%
rows=header.find_all("td")

head=[]
for i in range(len(rows)):
    print(rows[i])
# Out:
# <td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Player</span></div></td>
# <td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Span</span></div></td>
# <td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Mat</span></div></td>
# <td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Inns</span></div></td>
# <td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">NO</span></div></td>
# <td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Runs</span></div></td>
# <td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">HS</span></div></td>
# <td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer">Ave</span></div></td>
# ...

# %%
rows=header.find_all("td")

head=[]
for i in range(len(rows)):
    
    soup1=rows[i]
    x=soup1.find("span",class_="ds-cursor-pointer")
    print(x)
    head.append(x.text)
# Out:
# <span class="ds-cursor-pointer">Player</span>
# <span class="ds-cursor-pointer">Span</span>
# <span class="ds-cursor-pointer">Mat</span>
# <span class="ds-cursor-pointer">Inns</span>
# <span class="ds-cursor-pointer">NO</span>
# <span class="ds-cursor-pointer">Runs</span>
# <span class="ds-cursor-pointer">HS</span>
# <span class="ds-cursor-pointer">Ave</span>
# <span class="ds-cursor-pointer">SR</span>
# <span class="ds-cursor-pointer">100</span>
# <span class="ds-cursor-pointer">50</span>
# <span class="ds-cursor-pointer">0</span>

# %%
head
# Out:
# ['Player',
#  'Span',
#  'Mat',
#  'Inns',
#  'NO',
#  'Runs',
#  'HS',
#  'Ave',
#  'SR',
#  '100',
#  '50',
#  '0']

# %%
# body = table.find("tbody")
# rows = body.find_all("tr", class_=["ds-table-row-compact-bottom", 'ds-table-row-compact-top'])

# data = []

# for i in range(len(rows)):  

#     temp = []
#     if rows[i]:
#         tdata = rows[i].find_all("td", class_="ds-min-w-max")
#         for j in tdata:
#             temp.append(j.text)

#         if 'ds-table-row-compact-top' in rows[i].get('class', []):
#             if data and temp:
#                 data[-1].append(temp[0])
#             # Add an empty list to represent a separation between rows
#             data.append([])
#         elif data:
#             # Add the player's data to the last list in data
#             data[-1].extend(temp)

# print(data)

# %%
body=table.find("tbody")
rows = body.select("tr.ds-table-row-compact-bottom, tr.ds-table-row-compact-top")

data = []
for row in rows:
    temp = []
    tdata = row.find_all("td", class_="ds-min-w-max")
    for i in range(len(tdata)):
        # print(tdata[i].text)
        if i==0 and tdata[i].find("a"):
            url1="https://www.espncricinfo.com/"+tdata[i].find("a").get('href')

            r1=requests.get(url1)

            inside= BeautifulSoup(r1.text,"html.parser")

            name1 = inside.find("div", class_="ds-bg-raw-black/85")
            # print(name1)
            # print(name1.find("h1","ds-text-title-l ds-font-bold").text)
            temp.append(name1.find("h1","ds-text-title-l ds-font-bold").text)
        else:
            temp.append(tdata[i].text)
    data.append(temp)

# %%
body=table.find("tbody")
rows = body.select("tr.ds-table-row-compact-bottom, tr.ds-table-row-compact-top")

data = []
for row in rows:
    temp = []
    tdata = row.find_all("td", class_="ds-min-w-max")
    for td in tdata:
        print(td.text)
        temp.append(td.text)

    data.append(temp)
# Out:
# SA Abbott
# 2023-2023
# 1
# -
# 0
# -
# -
# -
# 0.00
# -
# -
# -
# Australia
# Abdullah Shafique
# 2023-2023
# 8
# 8
# 0
# 336
# 113
# 42.00
# 93.33
# 1
# 3
# 1
# Pakistan
# CN Ackermann
# 2023-2023
# 9
# 9
# 0
# 216
# 69
# 24.00
# 82.12
# -
# 1
# 1
# Netherlands
# Agha Salman
# 2023-2023
# 3
# 1
# 0
# 51
# 51
# 51.00
# 113.33
# -
# 1
# -
# Pakistan
# MM Ali
# 2023-2023
# 6
# 6
# 0
# 95
# 42
# 15.83
# 74.80
# -
# -
# -
# England
# KIC Asalanka
# 2023-2023
# 9
# 8
# 0
# 288
# 108
# 36.00
# 85.20
# 1
# 1
# -
# Sri Lanka
# R Ashwin
# 2023-2023
# 1
# -
# 0
# -
# -
# -
# 0.00
# -
# -
# -
# India
# AAP Atkinson
# 2023-2023
# 3
# 3
# 1
# 37
# 35
# 18.50
# 160.86
# -
# -
# 1
# England
# Azmatullah Omarzai
# 2023-2023
# 9
# 8
# 3
# 353
# 97*
# 70.60
# 97.78
# -
# 3
# -
# Afghanistan
# Babar Azam
# 2023-2023
# 9
# 9
# 1
# 320
# 74
# 40.00
# 82.90
# -
# 4
# -
# Pakistan
# JM Bairstow
# 2023-2023
# 9
# 9
# 0
# 215
# 59
# 23.88
# 88.47
# -
# 2
# 1
# England
# W Barresi
# 2023-2023
# 4
# 4
# 0
# ...

# %%
data[1]
# Out:
# ['Australia']

# %%
head
# Out:
# ['Player',
#  'Span',
#  'Mat',
#  'Inns',
#  'NO',
#  'Runs',
#  'HS',
#  'Ave',
#  'SR',
#  '100',
#  '50',
#  '0']

# %%
df = pd.DataFrame(data, columns=head)

# %%
df
# Out:
#                 Player       Span   Mat  Inns    NO  Runs    HS    Ave     SR  \
# 0          Sean Abbott  2023-2023     1     -     0     -     -      -   0.00
# 1            Australia       None  None  None  None  None  None   None   None
# 2    Abdullah Shafique  2023-2023     8     8     0   336   113  42.00  93.33
# 3             Pakistan       None  None  None  None  None  None   None   None
# 4      Colin Ackermann  2023-2023     9     9     0   216    69  24.00  82.12
# ..                 ...        ...   ...   ...   ...   ...   ...    ...    ...
# 297              India       None  None  None  None  None  None   None   None
# 298         Will Young  2023-2023     6     6     0   206    70  34.33  83.73
# 299        New Zealand       None  None  None  None  None  None   None   None
# 300         Adam Zampa  2023-2023    11     6     3    48    29  16.00  80.00
# 301          Australia       None  None  None  None  None  None   None   None
#
#       100    50     0
# ...

# %%
df_players=df[~df['Span'].isna()].reset_index(drop=True)

# %%
df_country=df[df['Span'].isna()].reset_index(drop=True)

# %%
df_players
# Out:
#                 Player       Span Mat Inns NO Runs   HS    Ave      SR 100 50  \
# 0          Sean Abbott  2023-2023   1    -  0    -    -      -    0.00   -  -
# 1    Abdullah Shafique  2023-2023   8    8  0  336  113  42.00   93.33   1  3
# 2      Colin Ackermann  2023-2023   9    9  0  216   69  24.00   82.12   -  1
# 3          Agha Salman  2023-2023   3    1  0   51   51  51.00  113.33   -  1
# 4            Moeen Ali  2023-2023   6    6  0   95   42  15.83   74.80   -  -
# ..                 ...        ...  ..  ... ..  ...  ...    ...     ...  .. ..
# 146       Chris Woakes  2023-2023   8    8  1  131   51  18.71   84.51   -  1
# 147          Mark Wood  2023-2023   7    7  4   85  43*  28.33  130.76   -  -
# 148   Suryakumar Yadav  2023-2023   7    7  1  106   49  17.66  100.95   -  -
# 149         Will Young  2023-2023   6    6  0  206   70  34.33   83.73   -  2
# 150         Adam Zampa  2023-2023  11    6  3   48   29  16.00   80.00   -  -
#
#      0
# 0    -
# 1    1
# ...

# %%
df_country.rename(columns={'Player':'Country'}).reset_index()[['index','Country']]
# Out:
#      index      Country
# 0        0    Australia
# 1        1     Pakistan
# 2        2  Netherlands
# 3        3     Pakistan
# 4        4      England
# ..     ...          ...
# 146    146      England
# 147    147      England
# 148    148        India
# 149    149  New Zealand
# 150    150    Australia
#
# [151 rows x 2 columns]

# %%
df_final=df_players.reset_index().merge(df_country.rename(columns={'Player':'Country'}).reset_index()[['index','Country']])

# %%
df_final
# Out:
#      index             Player       Span Mat Inns NO Runs   HS    Ave      SR  \
# 0        0        Sean Abbott  2023-2023   1    -  0    -    -      -    0.00
# 1        1  Abdullah Shafique  2023-2023   8    8  0  336  113  42.00   93.33
# 2        2    Colin Ackermann  2023-2023   9    9  0  216   69  24.00   82.12
# 3        3        Agha Salman  2023-2023   3    1  0   51   51  51.00  113.33
# 4        4          Moeen Ali  2023-2023   6    6  0   95   42  15.83   74.80
# ..     ...                ...        ...  ..  ... ..  ...  ...    ...     ...
# 146    146       Chris Woakes  2023-2023   8    8  1  131   51  18.71   84.51
# 147    147          Mark Wood  2023-2023   7    7  4   85  43*  28.33  130.76
# 148    148   Suryakumar Yadav  2023-2023   7    7  1  106   49  17.66  100.95
# 149    149         Will Young  2023-2023   6    6  0  206   70  34.33   83.73
# 150    150         Adam Zampa  2023-2023  11    6  3   48   29  16.00   80.00
#
#     100 50  0      Country
# ...

# %%
df_final=df_final.drop(columns={'index'})[['Player','Country', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'SR', '100',
       '50', '0']]

# %%
df_final['Country'].value_counts().reset_index()
# Out:
#         Country  count
# 0     Sri Lanka     18
# 1     Australia     15
# 2      Pakistan     15
# 3   Netherlands     15
# 4       England     15
# 5         India     15
# 6  South Africa     15
# 7   New Zealand     15
# 8    Bangladesh     15
# 9   Afghanistan     13

# %%
df_final.to_csv('batting_data.csv',index=False)

# %%
df_final
# Out:
#                        Player      Country       Span Mat Inns NO Runs   HS  \
# 0         Sean Anthony Abbott    Australia  2023-2023   1    -  0    -    -
# 1           Abdullah Shafique     Pakistan  2023-2023   8    8  0  336  113
# 2        Colin Niel Ackermann  Netherlands  2023-2023   9    9  0  216   69
# 3                 Agha Salman     Pakistan  2023-2023   3    1  0   51   51
# 4             Moeen Munir Ali      England  2023-2023   6    6  0   95   42
# ..                        ...          ...        ...  ..  ... ..  ...  ...
# 146  Christopher Roger Woakes      England  2023-2023   8    8  1  131   51
# 147          Mark Andrew Wood      England  2023-2023   7    7  4   85  43*
# 148    Suryakumar Ashok Yadav        India  2023-2023   7    7  1  106   49
# 149   William Alexander Young  New Zealand  2023-2023   6    6  0  206   70
# 150                Adam Zampa    Australia  2023-2023  11    6  3   48   29
#
#        Ave      SR 100 50  0
# ...
